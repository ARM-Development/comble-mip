# %% [markdown]
# # List of Planned Participants
#
# One of the key steps to planning a model intercomparison project (MIP) is determining who wants to participate.
#
# For this project, we solicited the community and requested that interested research groups sign up in a Google Spreadsheet. Let's read that in!

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read Data from Google Sheets
# Here is a link to the document
# - [Google Sheets Document](https://docs.google.com/spreadsheets/d/1h0BDDCCJTfIsdvHHNFyA17bpsNAL7405GG69IkC8qJs/edit?usp=sharing)

# %% [markdown]
# ## Interested Modeling Groups

# %%
model_list = pd.read_excel('https://docs.google.com/spreadsheets/d/' + 
                            '1h0BDDCCJTfIsdvHHNFyA17bpsNAL7405GG69IkC8qJs' +
                            '/export?gid=0&format=xlsx',
                            sheet_name='Models')
pd.set_option('display.max_colwidth', None)
model_list
# Out:
#                                                                     Participant Name(s)  \
# 0                                                Tim Juliano, Branko Kosovic, Lulin Xue
# 1                                                          Mikhail Ovchinnikov, Peng Wu
# 2                                           Florian Tornow, Ann Fridlind, Andy Ackerman
# 3                           Roel Neggers, Jan Chylik, Fredrik Jansson, Stephan de Roode
# 4   Gunilla Svensson, Michael Tjernström, Annica Ekman, Luisa Ickes, Hannah Frostenberg
# 5                                                                       Paquita Zuidema
# 6                                                                        Martin Koehler
# 7                                                  Kamal Kant Chandrakar, Hugh Morrison
# 8                                                                      Nicholas Szapiro
# 9                                                                             Xue Zheng
# ...

# %% [markdown]
# ## Interested Observational Groups

# %%
obs_list = pd.read_excel('https://docs.google.com/spreadsheets/d/' + 
                            '1h0BDDCCJTfIsdvHHNFyA17bpsNAL7405GG69IkC8qJs' +
                            '/export?gid=1705827066&format=xlsx',
                            sheet_name='Observations')
pd.set_option('display.max_colwidth', None)
obs_list
# Out:
#                                             Participant Name(s)  \
# 0                                                 Maria Cadeddu
# 1                                                   Damao Zhang
# 2                                                  David Turner
# 3                                                           NaN
# 4                                                           NaN
# 5                                 Pavlos Kollias, Zackary Mages
# 6                                  Peng Wu, Mikhail Ovchinnikov
# 7  Florian Tornow, Greg Elsaesser, Tim Juliano, Paquita Zuidema
# 8                                                   Zhibo Zhang
# 9                   Christian Lackner, Tim Juliano, Bart Geerts
#
#        Affiliation  \
# 0          DOE ANL
# 1             PNNL
# 2        NOAA ESRL
# 3              NaN
# 4              NaN
# 5              SBU
# 6             PNNL
# 7             GISS
# 8             UMBC
# 9  U Wyoming, NCAR
#
# ...
