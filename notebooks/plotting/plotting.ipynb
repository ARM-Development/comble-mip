# %%
# %run functions_plotting.py

# %%
## load all simulations located in subfolders of the given directory
var_vec_1d = ['lwp','rwp']
var_vec_2d = ['ua','va','qv','theta'] #,'va','qv','theta']
df_col_1d,df_col_2d = load_sims('../../output_les/',var_vec_1d,var_vec_2d)

## load ERA5 fields
era5_1d, era5_2d = load_era5(PATH='../../data_files/')

## load radiosondes
rs_dat = load_rs(PATH='../../data_files/')
# Out:
# ../../output_les/wrf/sandbox/init_geostrophic/WRF_LES_COMBLE-I.nc
# ../../output_les/dharma/sandbox/init_geostrophic/DHARMA_LES_COMBLE-I.nc
# ../../output_les/dharma/sandbox/init_era5/DHARMA_LES_COMBLE-I.nc
# ../../output_les/wrf/sandbox/init_geostrophic/WRF_LES_COMBLE-I.nc
# ../../output_les/dharma/sandbox/init_geostrophic/DHARMA_LES_COMBLE-I.nc
# ../../output_les/dharma/sandbox/init_era5/DHARMA_LES_COMBLE-I.nc
# ../../data_files/theta_temp_rh_sh_uvw_sst_along_trajectory_era5ml_28h_end_2020-03-13-18.nc
# ../../data_files/anxsondewnpnM1.b1.20200313.052700.cdf
# ../../data_files/anxsondewnpnM1.b1.20200313.112600.cdf
# ../../data_files/anxsondewnpnM1.b1.20200313.172600.cdf
# ../../data_files/anxsondewnpnM1.b1.20200313.232200.cdf

# %%
## plot all variables that have only time dependence
plot_1d(df_col_1d,var_vec_1d)

# %%
## plot all variables that have time and height dependence
#plot_2d(df_col2,var_vec_2d,[2,6,18])

## example where ERA5 and radiosonde are included
plot_2d(pd.concat([df_col_2d,era5_2d,rs_dat]),var_vec_2d,[4,12,18])
