# %% [markdown]
# # Requested Model Outputs
#
# Output variables are requested in three categories for LES:
#
# (1) domain-mean quantities and statistics every 10 minutes (time-averages reported at the end of each period) \
# (2) 2D quantities every 10 minutes (instantaneous) \
# (3) 3D variables every 1 hour (instantaneous) for comparison with satellite and ground-based observations
#
# For SCM, output variables are requested in one category:
#
# (4) quantities and statistics reported at end of each model physics time step \

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read Data from Google Sheets
#
# All requested output variables are listed in a [Google Sheets Document](https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/edit?usp=sharing), which is read in below one sheet at a time. We ask that you please open this document in your browser to see the minimum requested variables for your [initial SCM/small-domain LES submission](https://arm-development.github.io/comble-mip/timeline.html) (colored in green), as well as required variables for [application of EMC2](https://arm-development.github.io/comble-mip/emc2.html) to your model outputs (colored in red). Note that outputs enabling application of ECM2 are optional.

# %% [markdown]
# ### (1) LES: Domain-Mean Variables

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=0&format=xlsx',
                              sheet_name='Mean')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
vars_mean_list
# Out:
#                                                      standard_name  \
# 0                                                             time
# 1                                                           height
# 2                                                 surface_pressure
# 3                                              surface_temperature
# 4                                        surface_friction_velocity
# 5                                surface_upward_sensible_heat_flux
# 6                                  surface_upward_latent_heat_flux
# 7                                                   obukhov_length
# 8                    atmosphere_mass_content_of_liquid_cloud_water
# 9                            atmosphere_mass_content_of_rain_water
# 10                            atmosphere_mass_content_of_ice_water
# 11                                             cloud_area_fraction
# 12                                                   optical_depth
# 13                                   optical_depth_of_liquid_cloud
# 14                                   precipitation_flux_at_surface
# 15                      precipitation_flux_at_surface_in_ice_phase
# 16                                      toa_outgoing_longwave_flux
# 17                               surface_downwelling_longwave_flux
# 18                                 surface_upwelling_longwave_flux
# 19                                                    air_pressure
# 20                                                   eastward_wind
# 21                                                  northward_wind
# 22                                                 air_dry_density
# 23                                                 air_temperature
# 24                                        water_vapor_mixing_ratio
# 25                                               relative_humidity
# 26                                      relative_humidity_over_ice
# 27                                       air_potential_temperature
# 28                      specific_turbulent_kinetic_energy_resolved
# 29                           specific_turbulent_kinetic_energy_sgs
# 30                  mass_mixing_ratio_of_cloud_liquid_water_in_air
# 31                          mass_mixing_ratio_of_rain_water_in_air
# 32                           mass_mixing_ratio_of_cloud_ice_in_air
# 33                                mass_mixing_ratio_of_snow_in_air
# 34                             mass_mixing_ratio_of_graupel_in_air
# 35                          number_of_liquid_cloud_droplets_in_air
# 36                                     number_of_rain_drops_in_air
# 37                             number_of_cloud_ice_crystals_in_air
# 38                                  number_of_snow_crystals_in_air
# 39                               number_of_graupel_crystals_in_air
# 40                                   number_of_total_aerosol_mode1
# 41                                   number_of_total_aerosol_mode2
# 42                                   number_of_total_aerosol_mode3
# 43                        number_of_liquid_cloud_droplets_in_cloud
# 44                                 number_of_ice_crystals_in_cloud
# 45                     disspation_rate_of_turbulent_kinetic_energy
# 46                                             zonal_momentum_flux
# 47                                        meridional_momentum_flux
# 48                                 variance_of_upward_air_velocity
# 49                             vertical_flux_potential_temperature
# 50            vertical_flux_liquid_ice_water_potential_temperature
# 51                                       vertical_flux_water_vapor
# 52                                       vertical_flux_total_water
# 53                                   area_fraction_of_liquid_cloud
# 54                                       precipitation_flux_in_air
# 55                          precipitation_flux_in_air_in_ice_phase
# 56                                downwelling_longwave_flux_in_air
# 57                                  upwelling_longwave_flux_in_air
# 58  tendency_of_air_potential_temperature_due_to_radiative_heating
# 59       tendency_of_air_potential_temperature_due_to_microphysics
# 60             tendency_of_air_potential_temperature_due_to_mixing
# 61        tendency_of_water_vapor_mixing_ratio_due_to_microphysics
# 62              tendency_of_water_vapor_mixing_ratio_due_to_mixing
#
#    variable_id          units    dimensions  \
# 0         time              s             –
# 1           zf              m             –
# 2           ps             Pa          time
# 3           ts              K          time
# 4        ustar          m s-1          time
# 5         hfss          W m-2          time
# 6         hfls          W m-2          time
# 7           ol              m          time
# 8         lwpc         kg m-2          time
# 9         lwpr         kg m-2          time
# 10         iwp         kg m-2          time
# 11         clt              1          time
# 12          od              1          time
# 13        odlc              1          time
# 14          pr     kg m-2 s-1          time
# 15         pri     kg m-2 s-1          time
# 16        rlut          W m-2          time
# 17        rlds          W m-2          time
# 18        rlus          W m-2          time
# 19          pa             Pa  time, height
# 20          ua          m s-1  time, height
# 21          va          m s-1  time, height
# 22        rhoa         kg m-3  time, height
# 23          ta              K  time, height
# 24          qv        kg kg-1  time, height
# 25         hur              1  time, height
# 26        huri              1  time, height
# 27       theta              K  time, height
# 28     tke_res         m2 s-2  time, height
# 29     tke_sgs         m2 s-2  time, height
# 30         qlc        kg kg-1  time, height
# 31         qlr        kg kg-1  time, height
# 32         qic        kg kg-1  time, height
# 33         qis        kg kg-1  time, height
# 34         qig        kg kg-1  time, height
# 35         nlc           kg-1  time, height
# 36         nlr           kg-1  time, height
# 37         nic           kg-1  time, height
# 38         nis           kg-1  time, height
# 39         nig           kg-1  time, height
# 40         na1           kg-1  time, height
# 41         na2           kg-1  time, height
# 42         na3           kg-1  time, height
# 43       nlcic           kg-1  time, height
# 44        niic           kg-1  time, height
# 45         eps         m2 s-3  time, height
# 46          uw         m2 s-2  time, height
# 47          vw         m2 s-2  time, height
# 48          w2         m2 s-2  time, height
# 49         wth        K m s-1  time, height
# 50       wthli        K m s-1  time, height
# 51         wqv  kg kg-1 m s-1  time, height
# 52         wqt  kg kg-1 m s-1  time, height
# 53         flc              1  time, height
# 54         prf     kg m-2 s-1  time, height
# 55        prfi     kg m-2 s-1  time, height
# 56         rld          W m-2  time, height
# 57         rlu          W m-2  time, height
# 58     dth_rad          K s-1  time, height
# 59   dth_micro          K s-1  time, height
# 60    dth_turb          K s-1  time, height
# 61    dq_micro    kg kg-1 s-1  time, height
# 62     dq_turb    kg kg-1 s-1  time, height
#
#                                                                                                                                                                                                                                                                                                    comment (10-min average reported at endpoints, green=minimum)
# 0                                                                                                                                                                                                                                                                                                                   dimension, seconds since 2020-03-12 18:00:00
# 1                                                                                                                                                                                                                                                                                                      dimension, altitude of mid-level points above sea surface
# 2                                                                                                                                                                                                                                                                                                                                                              –
# 3                                                                                                                                                                                                                                                                                                                                                              –
# 4                                                                                                                                                                                                                                                                                                                                                              –
# 5                                                                                                                                                                                                                                                                                                                                                              –
# 6                                                                                                                                                                                                                                                                                                                                                              –
# 7                                                                                                                                                                                                                                                                                                                                                              –
# 8                                   default breakdown to cloud water and rain in a bulk scheme or radius separated at 40 micrometers in a bin scheme; if additional categories are used in a bulk scheme (e.g., a drizzle class), provide additional standard_name variable_id (e.g., lwpd); all lwp* variables will be summed to obtain total liquid water path
# 9                                                                                                                                                                                                                                                                                                                                                              –
# 10                                                                                                                                                                                                                                                                                                                                    all ice-phase hydrometeors
# 11                                                                                                                                                                                                     fraction of atmospheric columns with total hydrometeor optical thickness > 2; may assume geometric scatterers; to be compared with satellite measurements
# 12                                                                                                                                                                                                                                                                                                                scene (all sky); mid-visible, all hydrometeors
# 13                                                                                                                                                                                                                                                                                                                  as for optical_depth but cloud droplets only
# 14                                                                                                                                                                                                                                                                                                                        liquid and ice phase, all hydrometeors
# 15                                                                                                                                                                                                                                                                                                                                   ice phase hydrometeors only
# 16                                                                                                                                                                                                                                                                                                                                          at top of atmosphere
# 17                                                                                                                                                                                                                                                                                                                                                             –
# 18                                                                                                                                                                                                                                                                                                                                                             –
# 19                                                                                                                                                                                                                                                                                                                                                             –
# 20                                                                                                                                                                                                                                                                                                                                                             –
# 21                                                                                                                                                                                                                                                                                                                                                             –
# 22                                                                                                                                                                                                                                                                                                                                                             –
# 23                                                                                                                                                                                                                                                                                                                                                             –
# 24                                                                                                                                                                                                                                                                                                                                                per kg dry air
# 25                                                                                                                                                                                                                                                                                                                                            relative to liquid
# 26                                                                                                                                                                                                                                                                                                                                               relative to ice
# 27                                                                                                                                                                                                                                                                                                                                                             –
# 28                                                                                                                                                                                                                                                                                                                                                 resolved only
# 29                                                                                                                                                                                                                                                                                                                                                      SGS only
# 30  scene (all sky) per kg dry air; default breakdown to cloud water and rain in a bulk scheme or radius separated at 40 micrometers in a bin scheme; if additional categories are used in a bulk scheme (e.g., a drizzle class), provide additional standard_name variable_id (e.g., qld); all ql* variables will be summed to obtain total liquid mixing ratio
# 31                                                                                                                                                                                                                                                                                                                                                             –
# 32                                                                                                                                                       default breakdown to cloud_ice, snow and graupel; if other categories are used, provide additional standard_name and qiX variable_id; all qi* variables will be summed to obtain total ice mixing ratio
# 33                                                                                                                                                                                                                                                                                                                                                             –
# 34                                                                                                                                                                                                                                                                                                                                                             –
# 35                                                                                                                                                                                                 scene (all sky) per kg dry air; default breakdown to cloud water and rain; if other categories are used, provide additional standard_name and nl* variable_id
# 36                                                                                                                                                                                                                                                                                                                                                             –
# 37                                                                                                                                                default breakdown to cloud_ice, snow and graupel; if other categories are used, provide additional standard_name and niX variable_id; all ni* variables will be summed to obtain total ice number mixing ratio
# 38                                                                                                                                                                                                                                                                                                                                                             –
# 39                                                                                                                                                                                                                                                                                                                                                             –
# 40                                                                                                                                                                                                                                                                          when using prognostic aerosol; scene (all sky); activated + unactivated: Aitken mode
# 41                                                                                                                                                                                                                                                                                                                                             accumulation mode
# 42                                                                                                                                                                                                                                                                                                                                                sea spray mode
# 43                                                                                                                                                                                                        per kg dry air where cloud water > 0.01 g/kg; breakdown to cloud water and rain in a bulk scheme or radius separated at 40 micrometers in a bin scheme
# 44                                                                                                                                                                                                                      total ice hydrometeors per kg dry air where cloud water > 0.01 g/kg; within liquid cloud boundaries in order to check immersion freezing
# 45                                                                                                                                                                                                                                                                                                       including numerical diffusion contributions if relevant
# 46                                                                                                                                                                                                                                                                                                                                     total (resolved plus SGS)
# 47                                                                                                                                                                                                                                                                                                                                     total (resolved plus SGS)
# 48                                                                                                                                                                                                                                                                                                                                     total (resolved plus SGS)
# 49                                                                                                                                                                                                                                                                                                                                     total (resolved plus SGS)
# 50                                                                                                                                                                                                                                                                                                       total (resolved plus SGS); include sedimentation fluxes
# 51                                                                                                                                                                                                                                                                                                                                     total (resolved plus SGS)
# 52                                                                                                                                                                                                                                                                             total (resolved plus SGS); vapor+all liquid+all ice; include sedimentation fluxes
# 53                                                                                                                                                                                                                                                                           fraction of cells with cloud water threshold of 0.01 g/kg, not including rain class
# 54                                                                                                                                                                                                                                                                                                                        liquid and ice phase, all hydrometeors
# 55                                                                                                                                                                                                                                                                                                                                                             –
# 56                                                                                                                                                                                                                                                                                                                                                             –
# 57                                                                                                                                                                                                                                                                                                                                                             –
# 58                                                                                                                                                                                                                                                                                                                                                             –
# 59                                                                                                                                                                                                                                                                                                                  including net condensation and precipitation
# 60                                                                                                                                                                                                                                                                                                                                      including surface fluxes
# 61                                                                                                                                                                                                                                                                                                                  including net condensation and precipitation
# 62                                                                                                                                                                                                                                                                                                                                      including surface fluxes

# %% [markdown]
# ### (2) LES: Two-Dimensional Fields

# %%
vars_2d_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=1756539842&format=xlsx',
                              sheet_name='2D')
pd.set_option('display.max_colwidth', None)
vars_2d_list
# Out:
#                                     standard_name variable id       units  \
# 0                                            time        time           s
# 1                                               x           x           m
# 2                                               y           y           m
# 3               surface_upward_sensible_heat_flux        hfss       W m-2
# 4                 surface_upward_latent_heat_flux        hfls       W m-2
# 5                       surface_friction_velocity       ustar       m s-1
# 6                           surface_eastward_wind          us       m s-1
# 7                          surface_northward_wind          vs       m s-1
# 8                   precipitation_flux_at_surface          pr  kg m-2 s-1
# 9         atmosphere_mass_content_of_liquid_water         lwp      kg m-2
# 10                 atmosphere_mass_content_of_ice         iwp      kg m-2
# 11                   atmosphere_optical_thickness         opt           1
# 12                                  pseudo-albedo         alb           1
# 13  toa_outgoing_longwave_flux_atmospheric_window       olr11           K
#
#     dimensions  \
# 0            –
# 1            –
# 2            –
# 3   time, x, y
# 4   time, x, y
# 5   time, x, y
# 6   time, x, y
# 7   time, x, y
# 8   time, x, y
# 9   time, x, y
# 10  time, x, y
# 11  time, x, y
# 12  time, x, y
# 13  time, x, y
#
#                                                                                        comment (10-min instantaneous)
# 0                                                                        dimension, seconds since 2020-03-12 18:00:00
# 1                                                                                                           dimension
# 2                                                                                                           dimension
# 3                                                                                                                   –
# 4                                                                                                                   –
# 5                                                                                                                   –
# 6   at 10-m for comparison with SAR satellite measurements (mid-point of first layer if using suggested grid spacing)
# 7   at 10-m for comparison with SAR satellite measurements (mid-point of first layer if using suggested grid spacing)
# 8                                                                                                    all hydrometeors
# 9                                                                                             all liquid hydrometeors
# 10                                                                                               all ice hydrometeors
# 11                                                                         all hydrometeors for comparison with VIIRS
# 12                                 opt/(opt+13), where opt = all hydrometeor optical depth as reported in domain-mean
# 13                            flux at top-of-atmosphere in window containing 10.8 µm, please specify wavelength range

# %% [markdown]
# ### (3) LES: Three-Dimensional Fields

# %%
vars_3d_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=1233994833&format=xlsx',
                              sheet_name='3D')
pd.set_option('display.max_colwidth', None)
vars_3d_list
# Out:
#                                      standard_name variable id    units  \
# 0                                             time        time        s
# 1                                                x           x        m
# 2                                                y           y        m
# 3                                           height          zf        m
# 4                                     air_pressure          pa       Pa
# 5                                    eastward_wind          ua    m s-1
# 6                                   northward_wind          va    m s-1
# 7                              upward_air_velocity          wa    m s-1
# 8                                  air_temperature          ta        K
# 9                                  air_dry_density        rhoa   kg m-3
# 10                        water_vapor_mixing_ratio          qv  kg kg-1
# 11  mass_mixing_ratio_of_cloud_liquid_water_in_air         qlc  kg kg-1
# 12          mass_mixing_ratio_of_rain_water_in_air         qlr  kg kg-1
# 13           mass_mixing_ratio_of_cloud_ice_in_air         qic  kg kg-1
# 14                mass_mixing_ratio_of_snow_in_air         qis  kg kg-1
# 15             mass_mixing_ratio_of_graupel_in_air         qig  kg kg-1
# 16                    number_of_dry_aerosol_in_air          na     kg-1
# 17                 number_of_cloud_droplets_in_air         nlc     kg-1
# 18                  number_of_rain_droplets_in_air         nlr     kg-1
# 19             number_of_cloud_ice_crystals_in_air         nic     kg-1
# 20                  number_of_snow_crystals_in_air         nis     kg-1
# 21               number_of_graupel_crystals_in_air         nig     kg-1
# 22     disspation_rate_of_turbulent_kinetic_energy         eps   m2 s-3
# 23  mass_weighted_fall_speed_of_liquid_cloud_water        vmlc  kg kg-1
# 24                mass_weighted_fall_speed_of_rain        vmlr  kg kg-1
# 25           mass_weighted_fall_speed_of_ice_cloud        vmic  kg kg-1
# 26                mass_weighted_fall_speed_of_snow        vmis  kg kg-1
# 27             mass_weighted_fall_speed_of_graupel        vmig  kg kg-1
# 28                        tendency_of_condensation   tend_cond      s-1
# 29                          tendency_of_deposition    tend_dep      s-1
# 30                              tendency_of_riming    tend_rim      s-1
#
#             dimensions  \
# 0                    –
# 1                    –
# 2                    –
# 3                    –
# 4         time, height
# 5   time, height, x, y
# 6   time, height, x, y
# 7   time, height, x, y
# 8   time, height, x, y
# 9   time, height, x, y
# 10  time, height, x, y
# 11  time, height, x, y
# 12  time, height, x, y
# 13  time, height, x, y
# 14  time, height, x, y
# 15  time, height, x, y
# 16  time, height, x, y
# 17  time, height, x, y
# 18  time, height, x, y
# 19  time, height, x, y
# 20  time, height, x, y
# 21  time, height, x, y
# 22  time, height, x, y
# 23      time, pressure
# 24      time, pressure
# 25      time, pressure
# 26      time, pressure
# 27      time, pressure
# 28  time, height, x, y
# 29  time, height, x, y
# 30  time, height, x, y
#
#                                                                                                                                                                                                   comment (60-min instantaneous, red=required for EMC2)
# 0                                                                                                                                                                                                          dimension, seconds since 2020-03-12 18:00:00
# 1                                                                                                                                                                                                                                             dimension
# 2                                                                                                                                                                                                                                             dimension
# 3                                                                                                                                                                                             dimension, altitude of mid-level points above sea surface
# 4                                                                                                                                                                                                                                                     –
# 5                                                                                                                                                                                                                                                     –
# 6                                                                                                                                                                                                                                                     –
# 7                                                                                                                                                                                                                                                     –
# 8                                                                                                                                                                                                                                                     –
# 9                                                                                                                                                                                                                                                     –
# 10                                                                                                                                                                                                                                       per kg dry air
# 11                                  per kg dry air; default breakdown to cloud water and rain; if other categories are used, provide additional standard_name and ql* variable_id; all ql* variables will be summed to obtain total liquid mixing ratio
# 12                                                                                                                                                                                                                                                    –
# 13                                              default breakdown to cloud_ice, snow and graupel; if other categories are used, provide additional standard_name and qiX variable_id; all qi* variables will be summed to obtain total ice mixing ratio
# 14                                                                                                                                                                                                                                                    –
# 15                                                                                                                                                                                                                                                    –
# 16                                                                                                                                                                                                        per kg dry air; when using prognostic aerosol
# 17                                                                                                                                                                                                                        when using prognostic aerosol
# 18                                                                                                                                                                                                                                                    –
# 19                                       default breakdown to cloud_ice, snow and graupel; if other categories are used, provide additional standard_name and niX variable_id; all ni* variables will be summed to obtain total ice number mixing ratio
# 20                                                                                                                                                                                                                                                    –
# 21                                                                                                                                                                                                                                                    –
# 22                                                                                                                                                                                              including numerical diffusion contributions if relevant
# 23  EMC2 uses mass-weighted fall-speed profiles for all hydrometeor classes and cloud types; alternatively sufficient information to calculate mass-weighted velocity per hydrometeor class (e.g., size-fall speed relationship and PSD reconstruction)
# 24                                                                                                                                                                                                                                                    –
# 25                                                                                                                                                        if other ice-phase categories are used, provide additional standard_name and vmi* variable_id
# 26                                                                                                                                                                                                                                                    –
# 27                                                                                                                                                                                                                                                    –
# 28                                                                                                             combined tendencies of cloud liquid and rain water mixing ratios due to condensation/evaporation (+ for condensation, - for evaporation)
# 29                                                                                                               tendency of ice mixing ratio due to deposition/sublimation; sum over all ice hydrometeor classes (+ for deposition, - for sublimation)
# 30                                                                                                                                                                     tendency of ice mixing ratio due to riming; sum over all ice hydrometeor classes

# %% [markdown]
# ### (4) SCM

# %%
vars_scm_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=1026157027&format=xlsx',
                              sheet_name='SCM')
pd.set_option('display.max_colwidth', None)
vars_scm_list
# Out:
#                                                      standard_name  \
# 0                                                             time
# 1                                                         pressure
# 2                                                 surface_pressure
# 3                                              surface_temperature
# 4                                        surface_friction_velocity
# 5                                surface_upward_sensible_heat_flux
# 6                                  surface_upward_latent_heat_flux
# 7                                                   obukhov_length
# 8                                                       pbl_height
# 9                                                 inversion_height
# 10                   atmosphere_mass_content_of_liquid_cloud_water
# 11                           atmosphere_mass_content_of_rain_water
# 12                            atmosphere_mass_content_of_ice_water
# 13                             area_fraction_cover_of_hydrometeors
# 14                             area_fraction_cover_of_liquid_cloud
# 15                  area_fraction_cover_of_convective_hydrometeors
# 16                                                   optical_depth
# 17                                   optical_depth_of_liquid_cloud
# 18                                   precipitation_flux_at_surface
# 19                            precipitation_flux_of_ice_at_surface
# 20                                      toa_outgoing_longwave_flux
# 21                               surface_downwelling_longwave_flux
# 22                                 surface_upwelling_longwave_flux
# 23                                                          height
# 24                                                   eastward_wind
# 25                                                  northward_wind
# 26                                                 air_dry_density
# 27                                                 air_temperature
# 28                                        water_vapor_mixing_ratio
# 29                                               relative_humidity
# 30                                      relative_humidity_over_ice
# 31                                       air_potential_temperature
# 32                  mass_mixing_ratio_of_cloud_liquid_water_in_air
# 33                          mass_mixing_ratio_of_rain_water_in_air
# 34                           mass_mixing_ratio_of_ice_water_in_air
# 35                                   area_fraction_of_hydrometeors
# 36                                   area_fraction_of_liquid_cloud
# 37                        area_fraction_of_convective_hydrometeors
# 38                                       precipitation_flux_in_air
# 39                          precipitation_flux_in_air_in_ice_phase
# 40                               specific_turbulent_kinetic_energy
# 41                     disspation_rate_of_turbulent_kinetic_energy
# 42                                             zonal_momentum_flux
# 43                                        meridional_momentum_flux
# 44                                 variance_of_upward_air_velocity
# 45                             vertical_flux_potential_temperature
# 46            vertical_flux_liquid_ice_water_potential_temperature
# 47                                       vertical_flux_water_vapor
# 48                                       vertical_flux_total_water
# 49                                    convection_updraft_mass_flux
# 50                                  convection_downdraft_mass_flux
# 51                                downwelling_longwave_flux_in_air
# 52                                  upwelling_longwave_flux_in_air
# 53  tendency_of_air_potential_temperature_due_to_radiative_heating
# 54       tendency_of_air_potential_temperature_due_to_microphysics
# 55             tendency_of_air_potential_temperature_due_to_mixing
# 56        tendency_of_water_vapor_mixing_ratio_due_to_microphysics
# 57              tendency_of_water_vapor_mixing_ratio_due_to_mixing
# 58                                   number_of_total_aerosol_mode1
# 59                                   number_of_total_aerosol_mode2
# 60                                   number_of_total_aerosol_mode3
# 61       mass_mixing_ratio_of_liquid_cloud_water_in_air_stratiform
# 62               mass_mixing_ratio_of_rain_water_in_air_stratiform
# 63                mass_mixing_ratio_of_ice_cloud_in_air_stratiform
# 64        mass_mixing_ratio_of_ice_precipitation_in_air_stratiform
# 65       mass_mixing_ratio_of_liquid_cloud_water_in_air_convective
# 66               mass_mixing_ratio_of_rain_water_in_air_convective
# 67                mass_mixing_ratio_of_ice_cloud_in_air_convective
# 68        mass_mixing_ratio_of_ice_precipitation_in_air_convective
# 69               number_of_liquid_cloud_droplets_in_air_stratiform
# 70                          number_of_rain_drops_in_air_stratiform
# 71                  number_of_ice_cloud_crystals_in_air_stratiform
# 72          number_of_ice_precipitation_crystals_in_air_stratiform
# 73            effective_radius_of_liquid_cloud_droplets_convective
# 74                             effective_radius_of_rain_convective
# 75                        effective_radius_of_ice_cloud_convective
# 76                effective_radius_of_ice_precipitation_convective
# 77                        area_fraction_of_liquid_cloud_stratiform
# 78                                area_fraction_of_rain_stratiform
# 79                           area_fraction_of_ice_cloud_stratiform
# 80                   area_fraction_of_ice_precipitation_stratiform
# 81                        area_fraction_of_liquid_cloud_convective
# 82                                area_fraction_of_rain_convective
# 83                           area_fraction_of_ice_cloud_convective
# 84                   area_fraction_of_ice_precipitation_convective
# 85       mass_weighted_fall_speed_of_liquid_cloud_water_stratiform
# 86                     mass_weighted_fall_speed_of_rain_stratiform
# 87                mass_weighted_fall_speed_of_ice_cloud_stratiform
# 88        mass_weighted_fall_speed_of_ice_precipitation_stratiform
# 89       mass_weighted_fall_speed_of_liquid_cloud_water_convective
# 90                     mass_weighted_fall_speed_of_rain_convective
# 91       mass_weighted_fall_speed_of_cloud_ice_crystals_convective
# 92        mass_weighted_fall_speed_of_ice_precipitation_convective
#
#    variable_id          units      dimensions  \
# 0         time              s               –
# 1           pa             Pa               –
# 2           ps             Pa            time
# 3           ts              K            time
# 4        ustar          m s-1            time
# 5         hfss          W m-2            time
# 6         hfls          W m-2            time
# 7           ol              m            time
# 8         pblh              m            time
# 9           zi              m            time
# 10        lwpc         kg m-2            time
# 11        lwpr         kg m-2            time
# 12         iwp         kg m-2            time
# 13          cf              1            time
# 14        cflc              1            time
# 15         cfc              1            time
# 16          od              1            time
# 17        odlc              1            time
# 18          pr     kg m-2 s-1            time
# 19         pri     kg m-2 s-1            time
# 20        rlut          W m-2            time
# 21        rlds          W m-2            time
# 22        rlus          W m-2            time
# 23          zf              m  time, pressure
# 24          ua          m s-1  time, pressure
# 25          va          m s-1  time, pressure
# 26        rhoa         kg m-3  time, pressure
# 27          ta              K  time, pressure
# 28          qv        kg kg-1  time, pressure
# 29         hur              1  time, pressure
# 30        huri              1  time, pressure
# 31       theta              K  time, pressure
# 32         qlc        kg kg-1  time, pressure
# 33         qlr        kg kg-1  time, pressure
# 34          qi        kg kg-1  time, pressure
# 35          fh              1  time, pressure
# 36         flc              1  time, pressure
# 37          fc              1  time, pressure
# 38         prf     kg m-2 s-1  time, pressure
# 39        prfi     kg m-2 s-1  time, pressure
# 40         tke         m2 s-2  time, pressure
# 41         eps         m2 s-3  time, pressure
# 42          uw         m2 s-2  time, pressure
# 43          vw         m2 s-2  time, pressure
# 44          w2         m2 s-2  time, pressure
# 45         wth        K m s-1  time, pressure
# 46       wthli        K m s-1  time, pressure
# 47         wqv  kg kg-1 m s-1  time, pressure
# 48         wqt  kg kg-1 m s-1  time, pressure
# 49        cmfu     kg m-2 s-1  time, pressure
# 50        cmfd     kg m-2 s-1  time, pressure
# 51         rld          W m-2  time, pressure
# 52         rlu          W m-2  time, pressure
# 53     dth_rad          K s-1  time, pressure
# 54   dth_micro          K s-1  time, pressure
# 55    dth_turb          K s-1  time, pressure
# 56    dq_micro            s-1  time, pressure
# 57     dq_turb            s-1  time, pressure
# 58         na1           kg-1  time, pressure
# 59         na2           kg-1  time, pressure
# 60         na3           kg-1  time, pressure
# 61        qlcs        kg kg-1  time, pressure
# 62        qlrs        kg kg-1  time, pressure
# 63        qics        kg kg-1  time, pressure
# 64        qips        kg kg-1  time, pressure
# 65        qlcc        kg kg-1  time, pressure
# 66        qlrc        kg kg-1  time, pressure
# 67        qicc        kg kg-1  time, pressure
# 68        qipc        kg kg-1  time, pressure
# 69        nlcs           kg-1  time, pressure
# 70        nlrs           kg-1  time, pressure
# 71        nics           kg-1  time, pressure
# 72        nips           kg-1  time, pressure
# 73       relcc              m  time, pressure
# 74       relrc              m  time, pressure
# 75       reicc              m  time, pressure
# 76       reipc              m  time, pressure
# 77        flcs              1  time, pressure
# 78        flrs              1  time, pressure
# 79        fics              1  time, pressure
# 80        fips              1  time, pressure
# 81        flcc              1  time, pressure
# 82        flrc              1  time, pressure
# 83        ficc              1  time, pressure
# 84        fipc              1  time, pressure
# 85       vmlcs          m s-1  time, pressure
# 86       vmlrs          m s-1  time, pressure
# 87       vmics          m s-1  time, pressure
# 88       vmips          m s-1  time, pressure
# 89       vmlcc          m s-1  time, pressure
# 90       vmlrc          m s-1  time, pressure
# 91       vmicc          m s-1  time, pressure
# 92       vmipc          m s-1  time, pressure
#
#                                                                                                                                                                                                                    comment (reported at end of each model physics time step, green=minimum, red=granularity enabling EMC2)
# 0                                                                                                                                                                                                                                                                             dimension, seconds since 2020-03-12 18:00:00
# 1                                                                                                                                                                                                                                                                            dimension, pressure at model mid-level points
# 2                                                                                                                                                                                                                                                                                                                        –
# 3                                                                                                                                                                                                                                                                                                                        –
# 4                                                                                                                                                                                                                                                                                                                        –
# 5                                                                                                                                                                                                                                                                                                                        –
# 6                                                                                                                                                                                                                                                                                                                        –
# 7                                                                                                                                                                                                                                                                                                                        –
# 8                                                                                                                                                                                                                                                                                PBL scheme layer thickness (if available)
# 9                                                                                                                                                                                                                                                  sharpest vertical gradient in air_potential_temperature (below 400 hPa)
# 10                                                                                                                                                                                                                                      scene (all sky); cloud water path in all classes (e.g., convective and stratiform)
# 11                                                                                                                                                                                                                                       scene (all sky); rain water path in all classes (e.g., convective and stratiform)
# 12                                                                                                                                                                                                                                                              scene (all sky); all ice-phase hydrometeors in all classes
# 13                                                                                                                                                                                                                                         all hydrometeors and cloud types (e.g., all phase in stratiform and convective)
# 14                                                                                                                                                                                                                   liquid cloud cover without precipitation, including all cloud types (e.g., stratiform and convective)
# 15                                                                                                                       all hydrometeors, default breakdown into convective versus non-convective (stratiform) coverage; if other or additional categories are used, provide additional standard_name and fc* variable_id
# 16                                                                                                                                                                                                                             scene (all sky); mid-visible, all hydrometeors and classes, may assume geometric scatterers
# 17                                                                                                                                                                                                                                                                         scene (all sky); mid-visible, cloud liquid only
# 18                                                                                                                                                                                                                                                                                       scene (all sky); all hydrometeors
# 19                                                                                                                                                                                                                                                                             scene (all sky); all ice phase hydrometeors
# 20                                                                                                                                                                                                                                                                                                                       –
# 21                                                                                                                                                                                                                                                                                                                       –
# 22                                                                                                                                                                                                                                                                                                                       –
# 23                                                                                                                                                                                                                                                                          altitude of mid-level points above sea surface
# 24                                                                                                                                                                                                                                                                                                                       –
# 25                                                                                                                                                                                                                                                                                                                       –
# 26                                                                                                                                                                                                                                                                                                          per kg dry air
# 27                                                                                                                                                                                                                                                                                                                       –
# 28                                                                                                                                                                                                                                                                                                                       –
# 29                                                                                                                                                                                                                                                                                                      relative to liquid
# 30                                                                                                                                                                                                                                                                                                         relative to ice
# 31                                                                                                                                                                                                                                                                                                                       –
# 32                                                                                                                                                                                                                  scene (all sky) per kg dry air; cloud water path only in all classes (e.g., convective and stratiform)
# 33                                                                                                                                                                                                                                                   rain water path only in all classes (e.g., convective and stratiform)
# 34                                                                                                                                                                                                                                                     all ice water path in all classes (e.g., convective and stratiform)
# 35                                                                                                                                                                                                                                         all hydrometeors and cloud types (e.g., all phase in stratiform and convective)
# 36                                                                                                                                                                                                                   liquid cloud cover without precipitation, including all cloud types (e.g., stratiform and convective)
# 37                                                                                                                                             all hydrometeors, default breakdown into convective versus non-convective; if other or additional categories are used, provide additional standard_name and fc* variable_id
# 38                                                                                                                                                                                                                                                                                       scene (all sky); all hydrometeors
# 39                                                                                                                                                                                                                                                                             scene (all sky); all ice phase hydrometeors
# 40                                                                                                                                                                                                                                                                                                                       –
# 41                                                                                                                                                                                                                                                                                                                       –
# 42                                                                                                                                                                                                                                                                                            parameterized turbulent flux
# 43                                                                                                                                                                                                                                                                                            parameterized turbulent flux
# 44                                                                                                                                                                                                                                                                                            parameterized turbulent flux
# 45                                                                                                                                                                                                                                                                                            parameterized turbulent flux
# 46                                                                                                                                                                                                                                                              parameterized turbulent flux; include sedimentation fluxes
# 47                                                                                                                                                                                                                                                                                            parameterized turbulent flux
# 48                                                                                                                                                                                                                                    parameterized turbulent flux; vapor+all liquid+all ice; include sedimentation fluxes
# 49                                                                                                                                                                                                                                                                                                                       –
# 50                                                                                                                                                                                                                                                                                                                       –
# 51                                                                                                                                                                                                                                                                                                                       –
# 52                                                                                                                                                                                                                                                                                                                       –
# 53                                                                                                                                                                                                                                                                                                         scene (all sky)
# 54                                                                                                                                                                                                                           including net condensation and precipitation in all classes (e.g., convective and stratiform)
# 55                                                                                                                                                                                                                                                                                                including surface fluxes
# 56                                                                                                                                                                                                                           including net condensation and precipitation in all classes (e.g., convective and stratiform)
# 57                                                                                                                                                                                                                                                                                                including surface fluxes
# 58                                                                                                                                                                                                                                    when using prognostic aerosol; scene (all sky); activated + unactivated: Aitken mode
# 59                                                                                                                                                                                                                                                                                                       accumulation mode
# 60                                                                                                                                                                                                                                                                                                          sea spray mode
# 61  scene (all sky) per kg dry air; default breakdown into cloud water and rain in stratiform and convective classes for application of EMC2 to ModelE3; if other categories are used, provide additional standard_name and ql* variable_id; all ql* variables supplied will be summed to obtain total liquid mixing ratio
# 62                                                                                                                                                                                                                                                                                                                       –
# 63                                                                                                               default breakdown as for liquid; if other ice-phase categories are used, provide additional standard_name and qiX variable_id; all qi* variables supplied will be summed to obtain total ice mixing ratio
# 64                                                                                                                                                                                                                                                                                                                       –
# 65                                                                                                                                                                                                                                                                                                                       –
# 66                                                                                                                                                                                                                                                                                                                       –
# 67                                                                                                                                                                                                                                                                                                                       –
# 68                                                                                                                                                                                                                                                                                                                       –
# 69                                                                                                                                                                                                      scene (all sky) per kg dry air; if other categories are used, provide additional standard_name and nl* variable_id
# 70                                                                                                                                                                                                                                                                                                                       –
# 71                                                                                                                                        if other ice-phase categories are used, provide additional standard_name and ni* variable_id; all ni* variables supplied will be summed to obtain total ice number concentration
# 72                                                                                                                                                                                                                                                                                                                       –
# 73                                                                                                                                                                                                                EMC2 uses effective radius for any hydrometeor or cloud class where number concentration is not provided
# 74                                                                                                                                                                                                                                                                                                                       –
# 75                                                                                                                                                                                                                                                                                                                       –
# 76                                                                                                                                                                                                                                                                                                                       –
# 77                                                                                                                                                                                                                                            EMC2 uses area fraction profiles for all hydrometeor classes and cloud types
# 78                                                                                                                                                                                                                                                                                                                       –
# 79                                                                                                                                                                                                                                  if other ice categories are used, provide additional standard_name and fi* variable_id
# 80                                                                                                                                                                                                                                                                                                                       –
# 81                                                                                                                                                                                                                                                                                                                       –
# 82                                                                                                                                                                                                                                                                                                                       –
# 83                                                                                                                                                                                                                                                                                                                       –
# 84                                                                                                                                                                                                                                                                                                                       –
# 85                                                                                                                                                                                                                                 EMC2 uses mass-weighted fall-speed profiles for all hydrometeor classes and cloud types
# 86                                                                                                                                                                                                                                                                                                                       –
# 87                                                                                                                                                                                                                           if other ice-phase categories are used, provide additional standard_name and vmi* variable_id
# 88                                                                                                                                                                                                                                                                                                                       –
# 89                                                                                                                                                                                                                                                                                                                       –
# 90                                                                                                                                                                                                                                                                                                                       –
# 91                                                                                                                                                                                                                                                                                                                       –
# 92                                                                                                                                                                                                                                                                                                                       –
