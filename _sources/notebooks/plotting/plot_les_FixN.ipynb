# %% [markdown]
# # Compare FixN LES Sims
# ## Updated as of 5/24/24
# * The below notebook allows one to compare large-eddy simulations.
# * All requested 1D and 2D variables are here read and plotted. "load_sims" reports variable that are missing. Lines will not show, if a variable is missing or if it contains missing values.
# * In case you find inconsistencies in the benchmark set or wish to expand the code, please contact Ann Fridlind (ann.fridlind@nasa.gov), Timothy Juliano (tjuliano@ucar.edu), and Florian Tornow (ft2544@columbia.edu).

# %%
# %run functions_plotting.py

keyword_all = 'FixN.'
sim_keyword_cm1 = 'cm1-p3/staged/CM1-P3_Lx25_dx100_'+keyword_all
sim_keyword_dales = 'DALES/sandbox/DALES_Lx25_dx100_'+keyword_all
sim_keyword_dharma = 'dharma/sandbox/DHARMA_Lx25_dx100_'+keyword_all
sim_keyword_icon = 'icon/staged/ICON_Lx25_dx100_'+keyword_all
sim_keyword_msu_sm = 'msu-rcc-les/sandbox/MSU_RCC_LES_SM_Lx25_dx100_'+keyword_all
sim_keyword_sam = 'sam-pnnl/sandbox/SAM_Lx25_dx100_'+keyword_all
sim_keyword_ucla = 'uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_'+keyword_all
sim_keyword_wrf = 'wrf/sandbox/WRF_Lx25_dx100_'+keyword_all

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=0&format=xlsx',
                              sheet_name='Mean')

## short names
var_vec_1d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time'])
var_vec_2d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time, height'])

## long names
var_vec_1d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time'])
var_vec_2d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time, height'])

## Units
var_vec_1d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time'])
var_vec_2d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time, height'])

# %%
df_col_1d_cm1,df_col_2d_cm1 = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_cm1)
#df_col_1d_dales,df_col_2d_dales = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_dales) # issue with pri
df_col_1d_dharma,df_col_2d_dharma = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_dharma)
#df_col_1d_icon,df_col_2d_icon = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_icon)
#df_col_1d_msu_sm,df_col_2d_msu_sm = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_msu_sm)
#df_col_1d_sam,df_col_2d_sam = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_sam)
#df_col_1d_ucla,df_col_2d_ucla = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_ucla)
df_col_1d_wrf,df_col_2d_wrf = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_wrf)
# Out:
# Loading variables: f(time)
# ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ps shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ts shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ustar shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# z0 shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# z0h shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# z0q shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# hfss shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# hfls shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ol shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# lwpc shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# lwpr shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# pr shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# pri not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rlut shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rlds shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rlus shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ssaf not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# pa shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ua shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# va shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rhoa shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# ta shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qv shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# hur shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# huri shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# theta shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# tke_sgs shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qlc shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qlr shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qic shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qis shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# qig shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nlc not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nlr shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nic shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nis not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nig not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# na1 not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# na2 not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# na3 not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# nlcic not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# niic shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# eps not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# uw not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# vw not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# w2 not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# wth not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# vf_thli not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# wqv not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# vf_qt not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# flc not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# prf not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# prfi not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rld not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# rlu not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dth_rad not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dth_micro shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dth_turb not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dq_micro shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dq_turb not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dna_micro_warm not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dna_micro_cold not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dna_turb not found in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dni_het shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dni_sip shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# dni_hom shows NAN values in ../../output_les/cm1-p3/staged/CM1-P3_Lx25_dx100_FixN.nc
# Loading variables: f(time)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# ssaf shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na1 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na2 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na3 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_micro_warm shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_micro_cold shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_turb shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# Loading variables: f(time)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# ssaf shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na1 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na2 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na3 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# eps shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# rld shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# rlu shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_micro_warm shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_micro_cold shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_turb shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_het shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_sip shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_hom shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# na1 shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# na2 shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# na3 shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# wth shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dth_micro shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dth_turb shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dq_turb shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dna_micro_warm shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dna_micro_cold shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dna_turb shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dni_het shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dni_sip shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# dni_hom shows NAN values in ../../output_les/msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# computing inversion height, cloud-top height, and cloud-top temperature
# using liquid(-ice) potential temperature
# DALES/sandbox/DALES_Lx25_dx100_FixN.nc
# cm1-p3/sandbox/CM1-P3_Lx25_dx100_FixN.nc
# dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# msu-rcc-les/sandbox/MSU_RCC_LES_DM_Lx25_dx100_FixN.nc
# sam-pnnl/sandbox/SAM_Lx25_dx100_FixN.nc
# uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_FixN.nc
# wrf/sandbox/WRF_Lx25_dx100_FixN.nc

# %%
## plot variables that have only time dependence
#plot_1d(pd.concat([df_col_1d_cm1,df_col_1d_dales,df_col_1d_dharma,df_col_1d_icon,df_col_1d_msu_sm,df_col_1d_sam,df_col_1d_ucla,df_col_1d_wrf]),
#                   var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units,
#                   plot_colors=['orange','gray','k','r','g','magenta','gold','lightskyblue'],plot_ls=['-','-','-','-','-','-','-','-'])
plot_1d(pd.concat([df_col_1d_cm1,df_col_1d_dharma,df_col_1d_wrf]),
                   var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units,
                   plot_colors=['orange','red','lightskyblue'],plot_ls=['-','-','-'])

# %%
# %run functions_plotting.py

## example where ERA5 and radiosonde are included
#plot_2d(pd.concat([df_col_2d_cm1,df_col_2d_dales,df_col_2d_dharma,df_col_2d_icon,df_col_2d_msu_sm,df_col_2d_sam,df_col_2d_ucla,df_col_2d_wrf]),
#                   var_vec_2d,times=[-1.5,0,3,9,18],z_max=6000,units=var_vec_2d_units,
#                   plot_colors=['orange','gray','k','r','g','magenta','gold','lightskyblue'])
plot_2d(pd.concat([df_col_2d_cm1,df_col_2d_dharma,df_col_2d_wrf]),
                   var_vec_2d,times=[-1.5,0,3,9,18],z_max=6000,units=var_vec_2d_units,
                   plot_colors=['orange','red','lightskyblue'])

# %%
var_vec_1d_spec = ['ustar','hfss','hfls','cth','ctt']
var_vec_1d_long_spec = np.hstack([[var_vec_1d_long[(var_vec_1d == vv)][0] for vv in var_vec_1d_spec[0:3]],['cloud-top height','cloud-top temperature']])
var_vec_1d_units_spec = np.hstack([[var_vec_1d_units[(var_vec_1d == vv)][0] for vv in var_vec_1d_spec[0:3]],['m','°C']])

# %%
plot_1d(df_col_1d,
        var_vec_1d_spec,longnames=var_vec_1d_long_spec,units=var_vec_1d_units_spec,
        plot_colors=['orange','k','r','g','magenta','gold','lightskyblue'],plot_ls=['-','-','-','-','-','-','-'])
