# %% [markdown]
# # Compare ProgNaNi LES Sims
# ## Updated as of 5/24/24
# * The below notebook allows one to compare large-eddy simulations.
# * All requested 1D and 2D variables are here read and plotted. "load_sims" reports variable that are missing. Lines will not show, if a variable is missing or if it contains missing values.
# * In case you find inconsistencies in the benchmark set or wish to expand the code, please contact Ann Fridlind (ann.fridlind@nasa.gov) and Florian Tornow (ft2544@columbia.edu).

# %%
# %run functions_plotting.py

## select simulations to plot
sim_keyword = 'dx100_ProgNaNi.'

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=0&format=xlsx',
                              sheet_name='Mean')

## short names
var_vec_1d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time'])
var_vec_2d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time, height'])

## long names
var_vec_1d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time'])
var_vec_2d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time, height'])

## Units
var_vec_1d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time'])
var_vec_2d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time, height'])

# %%
df_col_1d,df_col_2d = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword,subfolder='sand')
# Out:
# Loading variables: f(time)
# ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# ssaf shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# Loading variables: f(time,height)
# ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# na1 shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# na3 shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# niic shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# eps shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# uw shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# vw shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# w2 shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# wth shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# vf_thli shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# wqv shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# vf_qt shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# flc shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# prf shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# prfi shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# rld shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# rlu shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dth_rad shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dth_micro shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dth_turb shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dq_micro shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dq_turb shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dna_micro_warm shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dna_micro_cold shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dna_turb shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dni_het shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dni_sip shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# dni_hom shows NAN values in ../../output_les/icon/sandbox/ICON_Lx25_dx100_ProgNaNi.nc
# ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# qis shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# qig shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# nis shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# nig shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# wth shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# vf_thli shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# vf_qt shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dth_rad shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dth_micro shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dth_turb shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dna_micro_warm shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dna_micro_cold shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc
# dni_sip shows NAN values in ../../output_les/uclales-salsa/sandbox/UCLALES-SALSA_Lx25_dx100_ProgNaNi.nc

# %%
## plot variables that have only time dependence
plot_1d(pd.concat([df_col_1d]),
                   var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units,
                   plot_colors=['orange','k','r','g','magenta','gold','lightskyblue'],plot_ls=['-','-','-','-','-','-','-'])

# %%
# %run functions_plotting.py

## example where ERA5 and radiosonde are included
plot_2d(pd.concat([df_col_2d]),
                   var_vec_2d,times=[-1.5,0,3,9,18],z_max=6000,units=var_vec_2d_units,longnames=var_vec_2d_long,
                   plot_colors=['orange','k','r','g','magenta','gold','lightskyblue'])
# Out:
# temporal averaging over 1.0 h interval
