# %% [markdown]
# # Check all SCMs against LES for the "FixN" configuration
#
# * The below notebook compares single column model simulations (colors) against a set of LES benchmark simulations (shown in gray).
# * All requested 1D and 2D variables are here read and plotted. "load_sims" reports variable that are missing. Lines will not show, if a variable is missing or if it contains missing values.
# * In case you find inconsistencies in the benchmark set or wish to expand the code, please contact Ann Fridlind (ann.fridlind@nasa.gov), Timothy Juliano (tjuliano@ucar.edu), and Florian Tornow (ft2544@columbia.edu).

# %%
# %run functions_plotting.py

## select (grayed out) simulations to plot
sim_keyword_gray_1 = 'DHARMA_Lx25_dx100_FixN.'
sim_keyword_gray_2 = 'WRF_Lx25_dx100_FixN.'

## select LES run(s) of interest
#sim_keyword_col_les = 'DHARMA_Lx25_dx100_FixN_noice.'
sim_keyword_col_scm_1 = 'FixN_def_z0.nc'
#sim_keyword_col_scm_2 = 'FixN.nc'
#sim_keyword_col_scm_3 = 'FixN_alt'

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=1026157027&format=xlsx',
                              sheet_name='SCM')

## short names
var_vec_1d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time'])
var_vec_2d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time, layer'])

var_vec_2d = var_vec_2d[var_vec_2d!='zf']

## long names
var_vec_1d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time'])

## Units
var_vec_1d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time'])
var_vec_2d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time, layer'])

# %%
## load all simulations located in subfolders of the given directory
df_gray_1d_1,df_gray_2d_1 = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_gray_1,make_gray = 1,diag_zi_ctt=True)
df_gray_1d_2,df_gray_2d_2 = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_gray_2,make_gray = 1,diag_zi_ctt=True)

## example using LES
#df_col_1d_les,df_col_2d_les = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_les)

## example using SCM
df_col_1d_scm_1,df_col_2d_scm_1 = load_sims('../../output_scm/CCPP-SCM/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_scm_1,subfolder='sand',diag_zi_ctt=True)
#df_col_1d_scm_2,df_col_2d_scm_2 = load_sims('../../output_scm/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_scm_2,subfolder='sand')
#df_col_1d_scm_3,df_col_2d_scm_3 = load_sims('../../output_scm/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_scm_3,subfolder='sand')
# Out:
# Loading variables: f(time)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# pblh not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# zi not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# cf not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# cflc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# cfc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# ssaf shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# pe not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qi not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# fh not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# fc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# tke not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# cmfu not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# cmfd not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na1 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na2 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# na3 shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_micro_warm shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_micro_cold shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# dna_turb shows NAN values in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qlcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qlrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# qipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# nlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# nlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# nics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# nips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# relcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# relrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# reicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# reipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# flcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# flrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# fics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# fips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# flcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# flrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# ficc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# fipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmlcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmlrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# vmipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# computing inversion height, cloud-top height, and cloud-top temperature
# dharma/sandbox/DHARMA_Lx25_dx100_FixN.nc
# Loading variables: f(time)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# pblh not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# zi not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# cf not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# cflc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# cfc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# ssaf shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# pe not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qi not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# fh not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# fc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# tke not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# eps shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# cmfu not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# cmfd not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# rld shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# rlu shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na1 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na2 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# na3 shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_micro_warm shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_micro_cold shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dna_turb shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_het shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_sip shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# dni_hom shows NAN values in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qlcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qlrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# qipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# nlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# nlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# nics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# nips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# relcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# relrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# reicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# reipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# flcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# flrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# fics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# fips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# flcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# flrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# ficc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# fipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmlcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmlrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# vmipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# computing inversion height, cloud-top height, and cloud-top temperature
# wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# Loading variables: f(time)
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# z0h shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# z0q shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# ol shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# zi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# lwpc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# lwpr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# iwp shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# cf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# cflc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# cfc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# od shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# odlc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# pr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# pri shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# rlut shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# ssaf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# z0h shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# z0q shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# ol shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# zi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# lwpc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# lwpr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# iwp shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# cf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# cflc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# cfc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# od shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# odlc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# pr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# pri shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# rlut shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# ssaf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# z0h shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# z0q shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# ol shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# zi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# lwpc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# lwpr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# iwp shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# cf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# cflc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# cfc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# od shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# odlc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# pr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# pri shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# rlut shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# ssaf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# z0h shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# z0q shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# ol shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# zi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# lwpc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# lwpr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# iwp shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# cf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# cflc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# cfc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# od shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# odlc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# pr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# pri shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# rlut shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# ssaf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# z0h shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# z0q shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# ol shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# zi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# lwpc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# lwpr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# iwp shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# cf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# cflc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# cfc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# od shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# odlc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# pr shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# pri shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# rlut shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# ssaf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# Loading variables: f(time,height)
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# fh shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# flc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# fc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# prf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# prfi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# eps shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# w2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# wth shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vf_thli shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# wqv shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vf_qt shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# rld shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# rlu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dth_rad shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dth_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dth_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dq_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dq_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# na1 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# na2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# na3 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dna_micro_warm shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dna_micro_cold shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dna_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dni_het shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dni_sip shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# dni_hom shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# qipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# nlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# nlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# nics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# nips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# relcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# relrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# reicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# reipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# flcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# flrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# fics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# fips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# flcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# flrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# ficc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# fipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# vmipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# fh shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# flc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# fc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# prf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# prfi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# eps shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# w2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# wth shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vf_thli shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# wqv shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vf_qt shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# rld shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# rlu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dth_rad shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dth_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dth_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dq_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dq_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# na1 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# na2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# na3 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dna_micro_warm shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dna_micro_cold shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dna_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dni_het shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dni_sip shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# dni_hom shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# qipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# nlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# nlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# nics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# nips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# relcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# relrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# reicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# reipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# flcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# flrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# fics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# fips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# flcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# flrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# ficc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# fipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# vmipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# fh shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# flc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# fc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# prf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# prfi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# eps shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# w2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# wth shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vf_thli shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# wqv shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vf_qt shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# rld shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# rlu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dth_rad shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dth_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dth_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dq_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dq_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# na1 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# na2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# na3 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dna_micro_warm shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dna_micro_cold shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dna_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dni_het shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dni_sip shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# dni_hom shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# qipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# nlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# nlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# nics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# nips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# relcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# relrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# reicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# reipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# flcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# flrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# fics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# fips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# flcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# flrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# ficc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# fipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# vmipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# fh shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# flc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# fc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# prf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# prfi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# eps shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# w2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# wth shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vf_thli shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# wqv shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vf_qt shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# cmfu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# cmfd shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# rld shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# rlu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dth_rad shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dth_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dth_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dq_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dq_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# na1 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# na2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# na3 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dna_micro_warm shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dna_micro_cold shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dna_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dni_het shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dni_sip shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# dni_hom shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# qipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# nlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# nlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# nics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# nips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# relcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# relrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# reicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# reipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# flcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# flrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# fics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# fips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# flcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# flrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# ficc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# fipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# vmipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# fh shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# flc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# fc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# prf shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# prfi shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# eps shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# w2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# wth shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vf_thli shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# wqv shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vf_qt shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# rld shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# rlu shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dth_rad shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dth_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dth_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dq_micro shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dq_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# na1 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# na2 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# na3 shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dna_micro_warm shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dna_micro_cold shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dna_turb shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dni_het shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dni_sip shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# dni_hom shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# qipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# nlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# nlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# nics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# nips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# relcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# relrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# reicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# reipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# flcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# flrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# fics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# fips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# flcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# flrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# ficc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# fipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmlcs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmlrs shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmics shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmips shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmlcc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmlrc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmicc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# vmipc shows NAN values in ../../output_scm/CCPP-SCM/sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc
# computing inversion height, cloud-top height, and cloud-top temperature
# sandbox/CCPP-SCM-GFSv16_dx13000_FixN_def_z0.nc
# sandbox/CCPP-SCM-GFSv16_dx25000_FixN_def_z0.nc
# sandbox/CCPP-SCM-GFSv16_dx3000_FixN_def_z0.nc
# sandbox/CCPP-SCM-HRRR_dx3000_FixN_def_z0.nc
# sandbox/CCPP-SCM-RAP_dx13000_FixN_def_z0.nc

# %%
# plot variables that have only time dependence
plot_1d(pd.concat([df_gray_1d_1,df_gray_1d_2,df_col_1d_scm_1]),var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units)

# %%
# %run functions_plotting.py

## example where ERA5 and radiosonde are included
plot_2d(pd.concat([df_gray_2d_1,df_gray_2d_2,df_col_2d_scm_1]),var_vec = var_vec_2d,times=[-1.5,0,3,9,18],z_max=6000,units=var_vec_2d_units)## example where ERA5 and radiosonde are included
# Out:
# temporal averaging over 1.0 h interval
