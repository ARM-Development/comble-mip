# %% [markdown]
# # Check my SCM run
#
# * The below notebook allows to compare a single column model simulation against a set of benchmark simulations (shown in gray).
# * All requested 1D and 2D variables are here read and plotted. "load_sims" reports variable that are missing. Lines will not show, if a variable is missing or if it contains missing values.
# * In case you find inconsistencies in the benchmark set or wish to expand the code, please contact Ann Fridlind (ann.fridlind@nasa.gov), Timothy Juliano (tjuliano@ucar.edu), and Florian Tornow (ft2544@columbia.edu).

# %%
# %run functions_plotting.py

## select (grayed out) simulations to plot
sim_keyword_gray = 'dharma/sandbox/DHARMA_Lx25km_dx100_F'

## select LES run(s) of interest
sim_keyword_col_les = 'WRF_Lx25_dx100_FixN.'
sim_keyword_col_scm = 'ModelE3-Phys_FixN.'

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=0&format=xlsx',
                              sheet_name='Mean')

## short names
var_vec_1d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time'])
var_vec_2d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time, height'])

## long names
var_vec_1d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time'])

## Units
var_vec_1d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time'])
var_vec_2d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time, height'])

# %%
## load all simulations located in subfolders of the given directory
df_gray_1d,df_gray_2d = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_gray,make_gray = 1)

## example using LES
df_col_1d_les,df_col_2d_les = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_les)

## example using SCM
df_col_1d_scm,df_col_2d_scm = load_sims('../../output_scm/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_scm)
# Out:
# Loading variables: f(time)
# ../../output_les/dharma/sandbox/DHARMA_Lx25km_dx100_FixN.nc
# lwpc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25km_dx100_FixN.nc
# lwpr not found in ../../output_les/dharma/sandbox/DHARMA_Lx25km_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/dharma/sandbox/DHARMA_Lx25km_dx100_FixN.nc
# computing inversion height and cloud-top temperature
# Loading variables: f(time)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# lwpc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# lwpr not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# Loading variables: f(time,height)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN.nc
# computing inversion height and cloud-top temperature
# Loading variables: f(time)
# ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# clt not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# Loading variables: f(time,height)
# ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# tke_res not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# tke_sgs not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# qic not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# qis not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# qig not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# nlc not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# nlr not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# nic not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# nis not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# nig not found in ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# computing inversion height and cloud-top temperature

# %%
## plot variables that have only time dependence
plot_1d(pd.concat([df_gray_1d,df_col_1d_scm,df_col_1d_les]),var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units)

# %%
## example where ERA5 and radiosonde are included
plot_2d(pd.concat([df_gray_2d,df_col_2d_scm,df_col_2d_les]),var_vec = var_vec_2d,times=[-1.5,0,3,4,18],z_max=6000,units=var_vec_2d_units)
