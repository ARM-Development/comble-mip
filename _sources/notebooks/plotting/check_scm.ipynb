# %% [markdown]
# # Check my SCM run
#
# * The below notebook allows to compare a single column model simulation against a set of benchmark simulations (shown in gray).
# * All requested 1D and 2D variables are here read and plotted. "load_sims" reports variable that are missing. Lines will not show, if a variable is missing or if it contains missing values.
# * In case you find inconsistencies in the benchmark set or wish to expand the code, please contact Ann Fridlind (ann.fridlind@nasa.gov), Timothy Juliano (tjuliano@ucar.edu), and Florian Tornow (ft2544@columbia.edu).

# %%
# %run functions_plotting.py

## select (grayed out) simulations to plot
sim_keyword_gray = 'dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.'

## select LES run(s) of interest
sim_keyword_col_les = 'WRF_Lx25_dx100_FixN_def_zi_twj.'
sim_keyword_col_scm = 'ModelE3-Phys_FixN.'

# %%
vars_mean_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1Vl8jYGviet7EtXZuQiitrx4NSkV1x27aJAhxxjBb9zI/export?gid=1026157027&format=xlsx',
                              sheet_name='SCM')

## short names
var_vec_1d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time'])
var_vec_2d = np.asarray(vars_mean_list.variable_id[vars_mean_list.dimensions == 'time, pressure'])

var_vec_2d = var_vec_2d[var_vec_2d!='zf']

## long names
var_vec_1d_long = np.asarray(vars_mean_list.standard_name[vars_mean_list.dimensions == 'time'])

## Units
var_vec_1d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time'])
var_vec_2d_units = np.asarray(vars_mean_list.units[vars_mean_list.dimensions == 'time, pressure'])

# %%
## load all simulations located in subfolders of the given directory
df_gray_1d,df_gray_2d = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_gray,make_gray = 1)

## example using LES
df_col_1d_les,df_col_2d_les = load_sims('../../output_les/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_les)

## example using SCM
df_col_1d_scm,df_col_2d_scm = load_sims('../../output_scm/',var_vec_1d,var_vec_2d,t_shift=-2,keyword=sim_keyword_col_scm)
# Out:
# Loading variables: f(time)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# pblh not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# zi not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# cf not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# cflc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# cfc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# Loading variables: f(time,height)
# ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qi not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# fh not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# fc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# tke not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# cmfu not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# cmfd not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qlcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qlrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# qipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# nlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# nlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# nics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# nips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# relcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# relrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# reicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# reipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# flcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# flrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# fics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# fips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# flcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# flrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# ficc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# fipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmlcs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmlrs not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmics not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmips not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmlcc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmlrc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmicc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# vmipc not found in ../../output_les/dharma/sandbox/DHARMA_Lx25_dx200_FixN_spec_z0.nc
# Loading variables: f(time)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# pblh not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# zi not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# cf not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# cflc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# cfc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# Loading variables: f(time,height)
# ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qi not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# fh not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# fc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# tke not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# cmfu not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# cmfd not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qlcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qlrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# qipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# nlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# nlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# nics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# nips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# relcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# relrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# reicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# reipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# flcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# flrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# fics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# fips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# flcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# flrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# ficc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# fipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmlcs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmlrs not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmics not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmips not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmlcc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmlrc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmicc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# vmipc not found in ../../output_les/wrf/sandbox/WRF_Lx25_dx100_FixN_def_zi_twj.nc
# Loading variables: f(time)
# ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc
# Loading variables: f(time,height)
# ../../output_scm/modelE/sandbox/ModelE3-Phys_FixN.nc

# %%
# plot variables that have only time dependence
plot_1d(pd.concat([df_gray_1d,df_col_1d_scm,df_col_1d_les]),var_vec_1d,longnames=var_vec_1d_long,units=var_vec_1d_units)

# %%
## example where ERA5 and radiosonde are included
plot_2d(pd.concat([df_gray_2d,df_col_2d_scm,df_col_2d_les]),var_vec = var_vec_2d,times=[-1.5,0,3,4,18],z_max=6000,units=var_vec_2d_units)## example where ERA5 and radiosonde are included
